# %% [markdown]
# Parse settings.xml to get channel map info

# %%
import xml.etree.ElementTree as ET

# Initialize a dictionary to store all probes
all_probes_data = {}
    
for settings_xml_num in range(2, 14):
    settings_file_path = f'/Volumes/Tim/Neuropixel2.0/openephys_data/sync_and_probe2025-05-17_03-43-55/Record Node 117/settings_{settings_xml_num}.xml'

    # Load the settings.xml
    tree = ET.parse(settings_file_path)
    root = tree.getroot()

    # Parse each PROBE
    probes = root.findall(".//NP_PROBE")
    for i, probe in enumerate(probes):
        # Make an id for each probe including the settings file number so we can store it
        probe_id = f"settings_{settings_xml_num}_probe_{i}"

        # Get config preset name
        electrode_config_name = probe.get("electrodeConfigurationPreset")
        print(f"NP_PROBE {i}: electrodeConfigurationPreset = '{electrode_config_name}'")

        # Initialize channel map
        channel_map = {}

        # Parse CHANNELS
        channels_element = probe.find("CHANNELS")
        if channels_element is not None:
            for channel_name, shank_info in channels_element.attrib.items():
                if channel_name.startswith("CH"):
                    channel_num = int(channel_name[2:])
                    channel_map[channel_num] = {"shank_info": shank_info}

        # Parse ELECTRODE_XPOS
        xpos_element = probe.find("ELECTRODE_XPOS")
        if xpos_element is not None:
            for channel_name, xpos in xpos_element.attrib.items():
                if channel_name.startswith("CH"):
                    channel_num = int(channel_name[2:])
                    channel_map[channel_num]["xpos"] = int(xpos)

        # Parse ELECTRODE_YPOS
        ypos_element = probe.find("ELECTRODE_YPOS")
        if ypos_element is not None:
            for channel_name, ypos in ypos_element.attrib.items():
                if channel_name.startswith("CH"):
                    channel_num = int(channel_name[2:])
                    channel_map[channel_num]["ypos"] = int(ypos)

        # Save this probe
        all_probes_data[probe_id] = {
            "electrode_config_name": electrode_config_name,
            "channel_map": channel_map
        }

        # Print info
        for ch, info in sorted(channel_map.items()):
            print(f"CH{ch}: {info}")
        print("\n\n\n")

for probe in all_probes_data:
    print(probe)
# Out:
# NP_PROBE 0: electrodeConfigurationPreset = 'All Shanks 1-96'
# CH0: {'shank_info': '0:0', 'xpos': 8, 'ypos': 0}
# CH1: {'shank_info': '0:0', 'xpos': 40, 'ypos': 0}
# CH2: {'shank_info': '0:0', 'xpos': 8, 'ypos': 15}
# CH3: {'shank_info': '0:0', 'xpos': 40, 'ypos': 15}
# CH4: {'shank_info': '0:0', 'xpos': 8, 'ypos': 30}
# CH5: {'shank_info': '0:0', 'xpos': 40, 'ypos': 30}
# CH6: {'shank_info': '0:0', 'xpos': 8, 'ypos': 45}
# CH7: {'shank_info': '0:0', 'xpos': 40, 'ypos': 45}
# CH8: {'shank_info': '0:0', 'xpos': 8, 'ypos': 60}
# CH9: {'shank_info': '0:0', 'xpos': 40, 'ypos': 60}
# CH10: {'shank_info': '0:0', 'xpos': 8, 'ypos': 75}
# CH11: {'shank_info': '0:0', 'xpos': 40, 'ypos': 75}
# CH12: {'shank_info': '0:0', 'xpos': 8, 'ypos': 90}
# CH13: {'shank_info': '0:0', 'xpos': 40, 'ypos': 90}
# CH14: {'shank_info': '0:0', 'xpos': 8, 'ypos': 105}
# CH15: {'shank_info': '0:0', 'xpos': 40, 'ypos': 105}
# CH16: {'shank_info': '0:0', 'xpos': 8, 'ypos': 120}
# CH17: {'shank_info': '0:0', 'xpos': 40, 'ypos': 120}
# CH18: {'shank_info': '0:0', 'xpos': 8, 'ypos': 135}
# CH19: {'shank_info': '0:0', 'xpos': 40, 'ypos': 135}
# CH20: {'shank_info': '0:0', 'xpos': 8, 'ypos': 150}
# CH21: {'shank_info': '0:0', 'xpos': 40, 'ypos': 150}
# CH22: {'shank_info': '0:0', 'xpos': 8, 'ypos': 165}
# CH23: {'shank_info': '0:0', 'xpos': 40, 'ypos': 165}
# CH24: {'shank_info': '0:0', 'xpos': 8, 'ypos': 180}
# CH25: {'shank_info': '0:0', 'xpos': 40, 'ypos': 180}
# CH26: {'shank_info': '0:0', 'xpos': 8, 'ypos': 195}
# CH27: {'shank_info': '0:0', 'xpos': 40, 'ypos': 195}
# CH28: {'shank_info': '0:0', 'xpos': 8, 'ypos': 210}
# CH29: {'shank_info': '0:0', 'xpos': 40, 'ypos': 210}
# CH30: {'shank_info': '0:0', 'xpos': 8, 'ypos': 225}
# CH31: {'shank_info': '0:0', 'xpos': 40, 'ypos': 225}
# CH32: {'shank_info': '0:0', 'xpos': 8, 'ypos': 240}
# CH33: {'shank_info': '0:0', 'xpos': 40, 'ypos': 240}
# CH34: {'shank_info': '0:0', 'xpos': 8, 'ypos': 255}
# CH35: {'shank_info': '0:0', 'xpos': 40, 'ypos': 255}
# CH36: {'shank_info': '0:0', 'xpos': 8, 'ypos': 270}
# CH37: {'shank_info': '0:0', 'xpos': 40, 'ypos': 270}
# CH38: {'shank_info': '0:0', 'xpos': 8, 'ypos': 285}
# CH39: {'shank_info': '0:0', 'xpos': 40, 'ypos': 285}
# CH40: {'shank_info': '0:0', 'xpos': 8, 'ypos': 300}
# CH41: {'shank_info': '0:0', 'xpos': 40, 'ypos': 300}
# CH42: {'shank_info': '0:0', 'xpos': 8, 'ypos': 315}
# CH43: {'shank_info': '0:0', 'xpos': 40, 'ypos': 315}
# CH44: {'shank_info': '0:0', 'xpos': 8, 'ypos': 330}
# CH45: {'shank_info': '0:0', 'xpos': 40, 'ypos': 330}
# CH46: {'shank_info': '0:0', 'xpos': 8, 'ypos': 345}
# CH47: {'shank_info': '0:0', 'xpos': 40, 'ypos': 345}
# CH48: {'shank_info': '0:1', 'xpos': 258, 'ypos': 0}
# CH49: {'shank_info': '0:1', 'xpos': 290, 'ypos': 0}
# CH50: {'shank_info': '0:1', 'xpos': 258, 'ypos': 15}
# CH51: {'shank_info': '0:1', 'xpos': 290, 'ypos': 15}
# CH52: {'shank_info': '0:1', 'xpos': 258, 'ypos': 30}
# CH53: {'shank_info': '0:1', 'xpos': 290, 'ypos': 30}
# CH54: {'shank_info': '0:1', 'xpos': 258, 'ypos': 45}
# CH55: {'shank_info': '0:1', 'xpos': 290, 'ypos': 45}
# CH56: {'shank_info': '0:1', 'xpos': 258, 'ypos': 60}
# CH57: {'shank_info': '0:1', 'xpos': 290, 'ypos': 60}
# CH58: {'shank_info': '0:1', 'xpos': 258, 'ypos': 75}
# CH59: {'shank_info': '0:1', 'xpos': 290, 'ypos': 75}
# CH60: {'shank_info': '0:1', 'xpos': 258, 'ypos': 90}
# CH61: {'shank_info': '0:1', 'xpos': 290, 'ypos': 90}
# CH62: {'shank_info': '0:1', 'xpos': 258, 'ypos': 105}
# CH63: {'shank_info': '0:1', 'xpos': 290, 'ypos': 105}
# CH64: {'shank_info': '0:1', 'xpos': 258, 'ypos': 120}
# CH65: {'shank_info': '0:1', 'xpos': 290, 'ypos': 120}
# CH66: {'shank_info': '0:1', 'xpos': 258, 'ypos': 135}
# CH67: {'shank_info': '0:1', 'xpos': 290, 'ypos': 135}
# CH68: {'shank_info': '0:1', 'xpos': 258, 'ypos': 150}
# CH69: {'shank_info': '0:1', 'xpos': 290, 'ypos': 150}
# CH70: {'shank_info': '0:1', 'xpos': 258, 'ypos': 165}
# CH71: {'shank_info': '0:1', 'xpos': 290, 'ypos': 165}
# CH72: {'shank_info': '0:1', 'xpos': 258, 'ypos': 180}
# CH73: {'shank_info': '0:1', 'xpos': 290, 'ypos': 180}
# CH74: {'shank_info': '0:1', 'xpos': 258, 'ypos': 195}
# CH75: {'shank_info': '0:1', 'xpos': 290, 'ypos': 195}
# CH76: {'shank_info': '0:1', 'xpos': 258, 'ypos': 210}
# CH77: {'shank_info': '0:1', 'xpos': 290, 'ypos': 210}
# CH78: {'shank_info': '0:1', 'xpos': 258, 'ypos': 225}
# CH79: {'shank_info': '0:1', 'xpos': 290, 'ypos': 225}
# CH80: {'shank_info': '0:1', 'xpos': 258, 'ypos': 240}
# CH81: {'shank_info': '0:1', 'xpos': 290, 'ypos': 240}
# CH82: {'shank_info': '0:1', 'xpos': 258, 'ypos': 255}
# CH83: {'shank_info': '0:1', 'xpos': 290, 'ypos': 255}
# CH84: {'shank_info': '0:1', 'xpos': 258, 'ypos': 270}
# CH85: {'shank_info': '0:1', 'xpos': 290, 'ypos': 270}
# CH86: {'shank_info': '0:1', 'xpos': 258, 'ypos': 285}
# CH87: {'shank_info': '0:1', 'xpos': 290, 'ypos': 285}
# CH88: {'shank_info': '0:1', 'xpos': 258, 'ypos': 300}
# CH89: {'shank_info': '0:1', 'xpos': 290, 'ypos': 300}
# CH90: {'shank_info': '0:1', 'xpos': 258, 'ypos': 315}
# CH91: {'shank_info': '0:1', 'xpos': 290, 'ypos': 315}
# CH92: {'shank_info': '0:1', 'xpos': 258, 'ypos': 330}
# CH93: {'shank_info': '0:1', 'xpos': 290, 'ypos': 330}
# CH94: {'shank_info': '0:1', 'xpos': 258, 'ypos': 345}
# CH95: {'shank_info': '0:1', 'xpos': 290, 'ypos': 345}
# CH96: {'shank_info': '0:0', 'xpos': 8, 'ypos': 360}
# CH97: {'shank_info': '0:0', 'xpos': 40, 'ypos': 360}
# CH98: {'shank_info': '0:0', 'xpos': 8, 'ypos': 375}
# CH99: {'shank_info': '0:0', 'xpos': 40, 'ypos': 375}
# CH100: {'shank_info': '0:0', 'xpos': 8, 'ypos': 390}
# CH101: {'shank_info': '0:0', 'xpos': 40, 'ypos': 390}
# CH102: {'shank_info': '0:0', 'xpos': 8, 'ypos': 405}
# CH103: {'shank_info': '0:0', 'xpos': 40, 'ypos': 405}
# CH104: {'shank_info': '0:0', 'xpos': 8, 'ypos': 420}
# CH105: {'shank_info': '0:0', 'xpos': 40, 'ypos': 420}
# CH106: {'shank_info': '0:0', 'xpos': 8, 'ypos': 435}
# CH107: {'shank_info': '0:0', 'xpos': 40, 'ypos': 435}
# CH108: {'shank_info': '0:0', 'xpos': 8, 'ypos': 450}
# CH109: {'shank_info': '0:0', 'xpos': 40, 'ypos': 450}
# CH110: {'shank_info': '0:0', 'xpos': 8, 'ypos': 465}
# CH111: {'shank_info': '0:0', 'xpos': 40, 'ypos': 465}
# CH112: {'shank_info': '0:0', 'xpos': 8, 'ypos': 480}
# CH113: {'shank_info': '0:0', 'xpos': 40, 'ypos': 480}
# CH114: {'shank_info': '0:0', 'xpos': 8, 'ypos': 495}
# CH115: {'shank_info': '0:0', 'xpos': 40, 'ypos': 495}
# CH116: {'shank_info': '0:0', 'xpos': 8, 'ypos': 510}
# CH117: {'shank_info': '0:0', 'xpos': 40, 'ypos': 510}
# CH118: {'shank_info': '0:0', 'xpos': 8, 'ypos': 525}
# CH119: {'shank_info': '0:0', 'xpos': 40, 'ypos': 525}
# CH120: {'shank_info': '0:0', 'xpos': 8, 'ypos': 540}
# CH121: {'shank_info': '0:0', 'xpos': 40, 'ypos': 540}
# CH122: {'shank_info': '0:0', 'xpos': 8, 'ypos': 555}
# CH123: {'shank_info': '0:0', 'xpos': 40, 'ypos': 555}
# CH124: {'shank_info': '0:0', 'xpos': 8, 'ypos': 570}
# CH125: {'shank_info': '0:0', 'xpos': 40, 'ypos': 570}
# CH126: {'shank_info': '0:0', 'xpos': 8, 'ypos': 585}
# CH127: {'shank_info': '0:0', 'xpos': 40, 'ypos': 585}
# CH128: {'shank_info': '0:0', 'xpos': 8, 'ypos': 600}
# CH129: {'shank_info': '0:0', 'xpos': 40, 'ypos': 600}
# CH130: {'shank_info': '0:0', 'xpos': 8, 'ypos': 615}
# CH131: {'shank_info': '0:0', 'xpos': 40, 'ypos': 615}
# CH132: {'shank_info': '0:0', 'xpos': 8, 'ypos': 630}
# CH133: {'shank_info': '0:0', 'xpos': 40, 'ypos': 630}
# CH134: {'shank_info': '0:0', 'xpos': 8, 'ypos': 645}
# CH135: {'shank_info': '0:0', 'xpos': 40, 'ypos': 645}
# CH136: {'shank_info': '0:0', 'xpos': 8, 'ypos': 660}
# CH137: {'shank_info': '0:0', 'xpos': 40, 'ypos': 660}
# CH138: {'shank_info': '0:0', 'xpos': 8, 'ypos': 675}
# CH139: {'shank_info': '0:0', 'xpos': 40, 'ypos': 675}
# CH140: {'shank_info': '0:0', 'xpos': 8, 'ypos': 690}
# CH141: {'shank_info': '0:0', 'xpos': 40, 'ypos': 690}
# CH142: {'shank_info': '0:0', 'xpos': 8, 'ypos': 705}
# CH143: {'shank_info': '0:0', 'xpos': 40, 'ypos': 705}
# CH144: {'shank_info': '0:1', 'xpos': 258, 'ypos': 360}
# CH145: {'shank_info': '0:1', 'xpos': 290, 'ypos': 360}
# CH146: {'shank_info': '0:1', 'xpos': 258, 'ypos': 375}
# CH147: {'shank_info': '0:1', 'xpos': 290, 'ypos': 375}
# CH148: {'shank_info': '0:1', 'xpos': 258, 'ypos': 390}
# CH149: {'shank_info': '0:1', 'xpos': 290, 'ypos': 390}
# CH150: {'shank_info': '0:1', 'xpos': 258, 'ypos': 405}
# CH151: {'shank_info': '0:1', 'xpos': 290, 'ypos': 405}
# CH152: {'shank_info': '0:1', 'xpos': 258, 'ypos': 420}
# CH153: {'shank_info': '0:1', 'xpos': 290, 'ypos': 420}
# CH154: {'shank_info': '0:1', 'xpos': 258, 'ypos': 435}
# CH155: {'shank_info': '0:1', 'xpos': 290, 'ypos': 435}
# CH156: {'shank_info': '0:1', 'xpos': 258, 'ypos': 450}
# CH157: {'shank_info': '0:1', 'xpos': 290, 'ypos': 450}
# CH158: {'shank_info': '0:1', 'xpos': 258, 'ypos': 465}
# CH159: {'shank_info': '0:1', 'xpos': 290, 'ypos': 465}
# CH160: {'shank_info': '0:1', 'xpos': 258, 'ypos': 480}
# CH161: {'shank_info': '0:1', 'xpos': 290, 'ypos': 480}
# CH162: {'shank_info': '0:1', 'xpos': 258, 'ypos': 495}
# CH163: {'shank_info': '0:1', 'xpos': 290, 'ypos': 495}
# CH164: {'shank_info': '0:1', 'xpos': 258, 'ypos': 510}
# CH165: {'shank_info': '0:1', 'xpos': 290, 'ypos': 510}
# CH166: {'shank_info': '0:1', 'xpos': 258, 'ypos': 525}
# CH167: {'shank_info': '0:1', 'xpos': 290, 'ypos': 525}
# CH168: {'shank_info': '0:1', 'xpos': 258, 'ypos': 540}
# CH169: {'shank_info': '0:1', 'xpos': 290, 'ypos': 540}
# CH170: {'shank_info': '0:1', 'xpos': 258, 'ypos': 555}
# CH171: {'shank_info': '0:1', 'xpos': 290, 'ypos': 555}
# CH172: {'shank_info': '0:1', 'xpos': 258, 'ypos': 570}
# CH173: {'shank_info': '0:1', 'xpos': 290, 'ypos': 570}
# CH174: {'shank_info': '0:1', 'xpos': 258, 'ypos': 585}
# CH175: {'shank_info': '0:1', 'xpos': 290, 'ypos': 585}
# CH176: {'shank_info': '0:1', 'xpos': 258, 'ypos': 600}
# CH177: {'shank_info': '0:1', 'xpos': 290, 'ypos': 600}
# CH178: {'shank_info': '0:1', 'xpos': 258, 'ypos': 615}
# CH179: {'shank_info': '0:1', 'xpos': 290, 'ypos': 615}
# CH180: {'shank_info': '0:1', 'xpos': 258, 'ypos': 630}
# CH181: {'shank_info': '0:1', 'xpos': 290, 'ypos': 630}
# CH182: {'shank_info': '0:1', 'xpos': 258, 'ypos': 645}
# CH183: {'shank_info': '0:1', 'xpos': 290, 'ypos': 645}
# CH184: {'shank_info': '0:1', 'xpos': 258, 'ypos': 660}
# CH185: {'shank_info': '0:1', 'xpos': 290, 'ypos': 660}
# CH186: {'shank_info': '0:1', 'xpos': 258, 'ypos': 675}
# CH187: {'shank_info': '0:1', 'xpos': 290, 'ypos': 675}
# CH188: {'shank_info': '0:1', 'xpos': 258, 'ypos': 690}
# CH189: {'shank_info': '0:1', 'xpos': 290, 'ypos': 690}
# CH190: {'shank_info': '0:1', 'xpos': 258, 'ypos': 705}
# CH191: {'shank_info': '0:1', 'xpos': 290, 'ypos': 705}
# CH192: {'shank_info': '0:2', 'xpos': 508, 'ypos': 0}
# CH193: {'shank_info': '0:2', 'xpos': 540, 'ypos': 0}
# CH194: {'shank_info': '0:2', 'xpos': 508, 'ypos': 15}
# CH195: {'shank_info': '0:2', 'xpos': 540, 'ypos': 15}
# CH196: {'shank_info': '0:2', 'xpos': 508, 'ypos': 30}
# CH197: {'shank_info': '0:2', 'xpos': 540, 'ypos': 30}
# CH198: {'shank_info': '0:2', 'xpos': 508, 'ypos': 45}
# CH199: {'shank_info': '0:2', 'xpos': 540, 'ypos': 45}
# CH200: {'shank_info': '0:2', 'xpos': 508, 'ypos': 60}
# CH201: {'shank_info': '0:2', 'xpos': 540, 'ypos': 60}
# CH202: {'shank_info': '0:2', 'xpos': 508, 'ypos': 75}
# CH203: {'shank_info': '0:2', 'xpos': 540, 'ypos': 75}
# CH204: {'shank_info': '0:2', 'xpos': 508, 'ypos': 90}
# CH205: {'shank_info': '0:2', 'xpos': 540, 'ypos': 90}
# CH206: {'shank_info': '0:2', 'xpos': 508, 'ypos': 105}
# CH207: {'shank_info': '0:2', 'xpos': 540, 'ypos': 105}
# CH208: {'shank_info': '0:2', 'xpos': 508, 'ypos': 120}
# CH209: {'shank_info': '0:2', 'xpos': 540, 'ypos': 120}
# CH210: {'shank_info': '0:2', 'xpos': 508, 'ypos': 135}
# CH211: {'shank_info': '0:2', 'xpos': 540, 'ypos': 135}
# CH212: {'shank_info': '0:2', 'xpos': 508, 'ypos': 150}
# CH213: {'shank_info': '0:2', 'xpos': 540, 'ypos': 150}
# CH214: {'shank_info': '0:2', 'xpos': 508, 'ypos': 165}
# CH215: {'shank_info': '0:2', 'xpos': 540, 'ypos': 165}
# CH216: {'shank_info': '0:2', 'xpos': 508, 'ypos': 180}
# CH217: {'shank_info': '0:2', 'xpos': 540, 'ypos': 180}
# CH218: {'shank_info': '0:2', 'xpos': 508, 'ypos': 195}
# CH219: {'shank_info': '0:2', 'xpos': 540, 'ypos': 195}
# CH220: {'shank_info': '0:2', 'xpos': 508, 'ypos': 210}
# CH221: {'shank_info': '0:2', 'xpos': 540, 'ypos': 210}
# CH222: {'shank_info': '0:2', 'xpos': 508, 'ypos': 225}
# CH223: {'shank_info': '0:2', 'xpos': 540, 'ypos': 225}
# CH224: {'shank_info': '0:2', 'xpos': 508, 'ypos': 240}
# CH225: {'shank_info': '0:2', 'xpos': 540, 'ypos': 240}
# CH226: {'shank_info': '0:2', 'xpos': 508, 'ypos': 255}
# CH227: {'shank_info': '0:2', 'xpos': 540, 'ypos': 255}
# CH228: {'shank_info': '0:2', 'xpos': 508, 'ypos': 270}
# CH229: {'shank_info': '0:2', 'xpos': 540, 'ypos': 270}
# CH230: {'shank_info': '0:2', 'xpos': 508, 'ypos': 285}
# CH231: {'shank_info': '0:2', 'xpos': 540, 'ypos': 285}
# CH232: {'shank_info': '0:2', 'xpos': 508, 'ypos': 300}
# CH233: {'shank_info': '0:2', 'xpos': 540, 'ypos': 300}
# CH234: {'shank_info': '0:2', 'xpos': 508, 'ypos': 315}
# CH235: {'shank_info': '0:2', 'xpos': 540, 'ypos': 315}
# CH236: {'shank_info': '0:2', 'xpos': 508, 'ypos': 330}
# CH237: {'shank_info': '0:2', 'xpos': 540, 'ypos': 330}
# CH238: {'shank_info': '0:2', 'xpos': 508, 'ypos': 345}
# CH239: {'shank_info': '0:2', 'xpos': 540, 'ypos': 345}
# CH240: {'shank_info': '0:3', 'xpos': 758, 'ypos': 0}
# CH241: {'shank_info': '0:3', 'xpos': 790, 'ypos': 0}
# CH242: {'shank_info': '0:3', 'xpos': 758, 'ypos': 15}
# CH243: {'shank_info': '0:3', 'xpos': 790, 'ypos': 15}
# CH244: {'shank_info': '0:3', 'xpos': 758, 'ypos': 30}
# CH245: {'shank_info': '0:3', 'xpos': 790, 'ypos': 30}
# CH246: {'shank_info': '0:3', 'xpos': 758, 'ypos': 45}
# CH247: {'shank_info': '0:3', 'xpos': 790, 'ypos': 45}
# CH248: {'shank_info': '0:3', 'xpos': 758, 'ypos': 60}
# CH249: {'shank_info': '0:3', 'xpos': 790, 'ypos': 60}
# CH250: {'shank_info': '0:3', 'xpos': 758, 'ypos': 75}
# CH251: {'shank_info': '0:3', 'xpos': 790, 'ypos': 75}
# CH252: {'shank_info': '0:3', 'xpos': 758, 'ypos': 90}
# CH253: {'shank_info': '0:3', 'xpos': 790, 'ypos': 90}
# CH254: {'shank_info': '0:3', 'xpos': 758, 'ypos': 105}
# CH255: {'shank_info': '0:3', 'xpos': 790, 'ypos': 105}
# CH256: {'shank_info': '0:3', 'xpos': 758, 'ypos': 120}
# CH257: {'shank_info': '0:3', 'xpos': 790, 'ypos': 120}
# CH258: {'shank_info': '0:3', 'xpos': 758, 'ypos': 135}
# CH259: {'shank_info': '0:3', 'xpos': 790, 'ypos': 135}
# CH260: {'shank_info': '0:3', 'xpos': 758, 'ypos': 150}
# CH261: {'shank_info': '0:3', 'xpos': 790, 'ypos': 150}
# CH262: {'shank_info': '0:3', 'xpos': 758, 'ypos': 165}
# CH263: {'shank_info': '0:3', 'xpos': 790, 'ypos': 165}
# CH264: {'shank_info': '0:3', 'xpos': 758, 'ypos': 180}
# CH265: {'shank_info': '0:3', 'xpos': 790, 'ypos': 180}
# CH266: {'shank_info': '0:3', 'xpos': 758, 'ypos': 195}
# CH267: {'shank_info': '0:3', 'xpos': 790, 'ypos': 195}
# CH268: {'shank_info': '0:3', 'xpos': 758, 'ypos': 210}
# CH269: {'shank_info': '0:3', 'xpos': 790, 'ypos': 210}
# CH270: {'shank_info': '0:3', 'xpos': 758, 'ypos': 225}
# CH271: {'shank_info': '0:3', 'xpos': 790, 'ypos': 225}
# CH272: {'shank_info': '0:3', 'xpos': 758, 'ypos': 240}
# CH273: {'shank_info': '0:3', 'xpos': 790, 'ypos': 240}
# CH274: {'shank_info': '0:3', 'xpos': 758, 'ypos': 255}
# CH275: {'shank_info': '0:3', 'xpos': 790, 'ypos': 255}
# CH276: {'shank_info': '0:3', 'xpos': 758, 'ypos': 270}
# CH277: {'shank_info': '0:3', 'xpos': 790, 'ypos': 270}
# CH278: {'shank_info': '0:3', 'xpos': 758, 'ypos': 285}
# CH279: {'shank_info': '0:3', 'xpos': 790, 'ypos': 285}
# CH280: {'shank_info': '0:3', 'xpos': 758, 'ypos': 300}
# CH281: {'shank_info': '0:3', 'xpos': 790, 'ypos': 300}
# CH282: {'shank_info': '0:3', 'xpos': 758, 'ypos': 315}
# CH283: {'shank_info': '0:3', 'xpos': 790, 'ypos': 315}
# CH284: {'shank_info': '0:3', 'xpos': 758, 'ypos': 330}
# CH285: {'shank_info': '0:3', 'xpos': 790, 'ypos': 330}
# CH286: {'shank_info': '0:3', 'xpos': 758, 'ypos': 345}
# CH287: {'shank_info': '0:3', 'xpos': 790, 'ypos': 345}
# CH288: {'shank_info': '0:2', 'xpos': 508, 'ypos': 360}
# CH289: {'shank_info': '0:2', 'xpos': 540, 'ypos': 360}
# CH290: {'shank_info': '0:2', 'xpos': 508, 'ypos': 375}
# CH291: {'shank_info': '0:2', 'xpos': 540, 'ypos': 375}
# CH292: {'shank_info': '0:2', 'xpos': 508, 'ypos': 390}
# CH293: {'shank_info': '0:2', 'xpos': 540, 'ypos': 390}
# CH294: {'shank_info': '0:2', 'xpos': 508, 'ypos': 405}
# CH295: {'shank_info': '0:2', 'xpos': 540, 'ypos': 405}
# CH296: {'shank_info': '0:2', 'xpos': 508, 'ypos': 420}
# CH297: {'shank_info': '0:2', 'xpos': 540, 'ypos': 420}
# CH298: {'shank_info': '0:2', 'xpos': 508, 'ypos': 435}
# CH299: {'shank_info': '0:2', 'xpos': 540, 'ypos': 435}
# CH300: {'shank_info': '0:2', 'xpos': 508, 'ypos': 450}
# CH301: {'shank_info': '0:2', 'xpos': 540, 'ypos': 450}
# CH302: {'shank_info': '0:2', 'xpos': 508, 'ypos': 465}
# CH303: {'shank_info': '0:2', 'xpos': 540, 'ypos': 465}
# CH304: {'shank_info': '0:2', 'xpos': 508, 'ypos': 480}
# CH305: {'shank_info': '0:2', 'xpos': 540, 'ypos': 480}
# CH306: {'shank_info': '0:2', 'xpos': 508, 'ypos': 495}
# CH307: {'shank_info': '0:2', 'xpos': 540, 'ypos': 495}
# CH308: {'shank_info': '0:2', 'xpos': 508, 'ypos': 510}
# CH309: {'shank_info': '0:2', 'xpos': 540, 'ypos': 510}
# CH310: {'shank_info': '0:2', 'xpos': 508, 'ypos': 525}
# CH311: {'shank_info': '0:2', 'xpos': 540, 'ypos': 525}
# CH312: {'shank_info': '0:2', 'xpos': 508, 'ypos': 540}
# CH313: {'shank_info': '0:2', 'xpos': 540, 'ypos': 540}
# CH314: {'shank_info': '0:2', 'xpos': 508, 'ypos': 555}
# CH315: {'shank_info': '0:2', 'xpos': 540, 'ypos': 555}
# CH316: {'shank_info': '0:2', 'xpos': 508, 'ypos': 570}
# CH317: {'shank_info': '0:2', 'xpos': 540, 'ypos': 570}
# CH318: {'shank_info': '0:2', 'xpos': 508, 'ypos': 585}
# CH319: {'shank_info': '0:2', 'xpos': 540, 'ypos': 585}
# CH320: {'shank_info': '0:2', 'xpos': 508, 'ypos': 600}
# CH321: {'shank_info': '0:2', 'xpos': 540, 'ypos': 600}
# CH322: {'shank_info': '0:2', 'xpos': 508, 'ypos': 615}
# CH323: {'shank_info': '0:2', 'xpos': 540, 'ypos': 615}
# CH324: {'shank_info': '0:2', 'xpos': 508, 'ypos': 630}
# CH325: {'shank_info': '0:2', 'xpos': 540, 'ypos': 630}
# CH326: {'shank_info': '0:2', 'xpos': 508, 'ypos': 645}
# CH327: {'shank_info': '0:2', 'xpos': 540, 'ypos': 645}
# CH328: {'shank_info': '0:2', 'xpos': 508, 'ypos': 660}
# CH329: {'shank_info': '0:2', 'xpos': 540, 'ypos': 660}
# CH330: {'shank_info': '0:2', 'xpos': 508, 'ypos': 675}
# CH331: {'shank_info': '0:2', 'xpos': 540, 'ypos': 675}
# CH332: {'shank_info': '0:2', 'xpos': 508, 'ypos': 690}
# CH333: {'shank_info': '0:2', 'xpos': 540, 'ypos': 690}
# CH334: {'shank_info': '0:2', 'xpos': 508, 'ypos': 705}
# CH335: {'shank_info': '0:2', 'xpos': 540, 'ypos': 705}
# CH336: {'shank_info': '0:3', 'xpos': 758, 'ypos': 360}
# CH337: {'shank_info': '0:3', 'xpos': 790, 'ypos': 360}
# CH338: {'shank_info': '0:3', 'xpos': 758, 'ypos': 375}
# CH339: {'shank_info': '0:3', 'xpos': 790, 'ypos': 375}
# CH340: {'shank_info': '0:3', 'xpos': 758, 'ypos': 390}
# CH341: {'shank_info': '0:3', 'xpos': 790, 'ypos': 390}
# CH342: {'shank_info': '0:3', 'xpos': 758, 'ypos': 405}
# CH343: {'shank_info': '0:3', 'xpos': 790, 'ypos': 405}
# CH344: {'shank_info': '0:3', 'xpos': 758, 'ypos': 420}
# CH345: {'shank_info': '0:3', 'xpos': 790, 'ypos': 420}
# CH346: {'shank_info': '0:3', 'xpos': 758, 'ypos': 435}
# CH347: {'shank_info': '0:3', 'xpos': 790, 'ypos': 435}
# CH348: {'shank_info': '0:3', 'xpos': 758, 'ypos': 450}
# CH349: {'shank_info': '0:3', 'xpos': 790, 'ypos': 450}
# CH350: {'shank_info': '0:3', 'xpos': 758, 'ypos': 465}
# CH351: {'shank_info': '0:3', 'xpos': 790, 'ypos': 465}
# CH352: {'shank_info': '0:3', 'xpos': 758, 'ypos': 480}
# CH353: {'shank_info': '0:3', 'xpos': 790, 'ypos': 480}
# CH354: {'shank_info': '0:3', 'xpos': 758, 'ypos': 495}
# CH355: {'shank_info': '0:3', 'xpos': 790, 'ypos': 495}
# CH356: {'shank_info': '0:3', 'xpos': 758, 'ypos': 510}
# CH357: {'shank_info': '0:3', 'xpos': 790, 'ypos': 510}
# CH358: {'shank_info': '0:3', 'xpos': 758, 'ypos': 525}
# CH359: {'shank_info': '0:3', 'xpos': 790, 'ypos': 525}
# CH360: {'shank_info': '0:3', 'xpos': 758, 'ypos': 540}
# CH361: {'shank_info': '0:3', 'xpos': 790, 'ypos': 540}
# CH362: {'shank_info': '0:3', 'xpos': 758, 'ypos': 555}
# CH363: {'shank_info': '0:3', 'xpos': 790, 'ypos': 555}
# CH364: {'shank_info': '0:3', 'xpos': 758, 'ypos': 570}
# CH365: {'shank_info': '0:3', 'xpos': 790, 'ypos': 570}
# CH366: {'shank_info': '0:3', 'xpos': 758, 'ypos': 585}
# CH367: {'shank_info': '0:3', 'xpos': 790, 'ypos': 585}
# CH368: {'shank_info': '0:3', 'xpos': 758, 'ypos': 600}
# CH369: {'shank_info': '0:3', 'xpos': 790, 'ypos': 600}
# CH370: {'shank_info': '0:3', 'xpos': 758, 'ypos': 615}
# CH371: {'shank_info': '0:3', 'xpos': 790, 'ypos': 615}
# CH372: {'shank_info': '0:3', 'xpos': 758, 'ypos': 630}
# CH373: {'shank_info': '0:3', 'xpos': 790, 'ypos': 630}
# CH374: {'shank_info': '0:3', 'xpos': 758, 'ypos': 645}
# CH375: {'shank_info': '0:3', 'xpos': 790, 'ypos': 645}
# CH376: {'shank_info': '0:3', 'xpos': 758, 'ypos': 660}
# CH377: {'shank_info': '0:3', 'xpos': 790, 'ypos': 660}
# CH378: {'shank_info': '0:3', 'xpos': 758, 'ypos': 675}
# CH379: {'shank_info': '0:3', 'xpos': 790, 'ypos': 675}
# CH380: {'shank_info': '0:3', 'xpos': 758, 'ypos': 690}
# CH381: {'shank_info': '0:3', 'xpos': 790, 'ypos': 690}
# CH382: {'shank_info': '0:3', 'xpos': 758, 'ypos': 705}
# CH383: {'shank_info': '0:3', 'xpos': 790, 'ypos': 705}
#
#
#
#
# NP_PROBE 1: electrodeConfigurationPreset = 'Shank 2 Bank A'
# CH0: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2160}
# CH1: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2160}
# CH2: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2175}
# CH3: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2175}
# CH4: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2190}
# CH5: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2190}
# CH6: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2205}
# CH7: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2205}
# CH8: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2220}
# CH9: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2220}
# CH10: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2235}
# CH11: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2235}
# CH12: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2250}
# CH13: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2250}
# CH14: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2265}
# CH15: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2265}
# CH16: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2280}
# CH17: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2280}
# CH18: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2295}
# CH19: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2295}
# CH20: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2310}
# CH21: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2310}
# CH22: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2325}
# CH23: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2325}
# CH24: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2340}
# CH25: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2340}
# CH26: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2355}
# CH27: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2355}
# CH28: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2370}
# CH29: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2370}
# CH30: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2385}
# CH31: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2385}
# CH32: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2400}
# CH33: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2400}
# CH34: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2415}
# CH35: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2415}
# CH36: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2430}
# CH37: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2430}
# CH38: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2445}
# CH39: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2445}
# CH40: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2460}
# CH41: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2460}
# CH42: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2475}
# CH43: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2475}
# CH44: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2490}
# CH45: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2490}
# CH46: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2505}
# CH47: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2505}
# CH48: {'shank_info': '0:1', 'xpos': 258, 'ypos': 0}
# CH49: {'shank_info': '0:1', 'xpos': 290, 'ypos': 0}
# CH50: {'shank_info': '0:1', 'xpos': 258, 'ypos': 15}
# CH51: {'shank_info': '0:1', 'xpos': 290, 'ypos': 15}
# CH52: {'shank_info': '0:1', 'xpos': 258, 'ypos': 30}
# CH53: {'shank_info': '0:1', 'xpos': 290, 'ypos': 30}
# CH54: {'shank_info': '0:1', 'xpos': 258, 'ypos': 45}
# CH55: {'shank_info': '0:1', 'xpos': 290, 'ypos': 45}
# CH56: {'shank_info': '0:1', 'xpos': 258, 'ypos': 60}
# CH57: {'shank_info': '0:1', 'xpos': 290, 'ypos': 60}
# CH58: {'shank_info': '0:1', 'xpos': 258, 'ypos': 75}
# CH59: {'shank_info': '0:1', 'xpos': 290, 'ypos': 75}
# CH60: {'shank_info': '0:1', 'xpos': 258, 'ypos': 90}
# CH61: {'shank_info': '0:1', 'xpos': 290, 'ypos': 90}
# CH62: {'shank_info': '0:1', 'xpos': 258, 'ypos': 105}
# CH63: {'shank_info': '0:1', 'xpos': 290, 'ypos': 105}
# CH64: {'shank_info': '0:1', 'xpos': 258, 'ypos': 120}
# CH65: {'shank_info': '0:1', 'xpos': 290, 'ypos': 120}
# CH66: {'shank_info': '0:1', 'xpos': 258, 'ypos': 135}
# CH67: {'shank_info': '0:1', 'xpos': 290, 'ypos': 135}
# CH68: {'shank_info': '0:1', 'xpos': 258, 'ypos': 150}
# CH69: {'shank_info': '0:1', 'xpos': 290, 'ypos': 150}
# CH70: {'shank_info': '0:1', 'xpos': 258, 'ypos': 165}
# CH71: {'shank_info': '0:1', 'xpos': 290, 'ypos': 165}
# CH72: {'shank_info': '0:1', 'xpos': 258, 'ypos': 180}
# CH73: {'shank_info': '0:1', 'xpos': 290, 'ypos': 180}
# CH74: {'shank_info': '0:1', 'xpos': 258, 'ypos': 195}
# CH75: {'shank_info': '0:1', 'xpos': 290, 'ypos': 195}
# CH76: {'shank_info': '0:1', 'xpos': 258, 'ypos': 210}
# CH77: {'shank_info': '0:1', 'xpos': 290, 'ypos': 210}
# CH78: {'shank_info': '0:1', 'xpos': 258, 'ypos': 225}
# CH79: {'shank_info': '0:1', 'xpos': 290, 'ypos': 225}
# CH80: {'shank_info': '0:1', 'xpos': 258, 'ypos': 240}
# CH81: {'shank_info': '0:1', 'xpos': 290, 'ypos': 240}
# CH82: {'shank_info': '0:1', 'xpos': 258, 'ypos': 255}
# CH83: {'shank_info': '0:1', 'xpos': 290, 'ypos': 255}
# CH84: {'shank_info': '0:1', 'xpos': 258, 'ypos': 270}
# CH85: {'shank_info': '0:1', 'xpos': 290, 'ypos': 270}
# CH86: {'shank_info': '0:1', 'xpos': 258, 'ypos': 285}
# CH87: {'shank_info': '0:1', 'xpos': 290, 'ypos': 285}
# CH88: {'shank_info': '0:1', 'xpos': 258, 'ypos': 300}
# CH89: {'shank_info': '0:1', 'xpos': 290, 'ypos': 300}
# CH90: {'shank_info': '0:1', 'xpos': 258, 'ypos': 315}
# CH91: {'shank_info': '0:1', 'xpos': 290, 'ypos': 315}
# CH92: {'shank_info': '0:1', 'xpos': 258, 'ypos': 330}
# CH93: {'shank_info': '0:1', 'xpos': 290, 'ypos': 330}
# CH94: {'shank_info': '0:1', 'xpos': 258, 'ypos': 345}
# CH95: {'shank_info': '0:1', 'xpos': 290, 'ypos': 345}
# CH96: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2520}
# CH97: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2520}
# CH98: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2535}
# CH99: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2535}
# CH100: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2550}
# CH101: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2550}
# CH102: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2565}
# CH103: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2565}
# CH104: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2580}
# CH105: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2580}
# CH106: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2595}
# CH107: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2595}
# CH108: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2610}
# CH109: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2610}
# CH110: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2625}
# CH111: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2625}
# CH112: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2640}
# CH113: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2640}
# CH114: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2655}
# CH115: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2655}
# CH116: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2670}
# CH117: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2670}
# CH118: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2685}
# CH119: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2685}
# CH120: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2700}
# CH121: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2700}
# CH122: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2715}
# CH123: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2715}
# CH124: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2730}
# CH125: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2730}
# CH126: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2745}
# CH127: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2745}
# CH128: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2760}
# CH129: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2760}
# CH130: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2775}
# CH131: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2775}
# CH132: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2790}
# CH133: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2790}
# CH134: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2805}
# CH135: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2805}
# CH136: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2820}
# CH137: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2820}
# CH138: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2835}
# CH139: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2835}
# CH140: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2850}
# CH141: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2850}
# CH142: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2865}
# CH143: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2865}
# CH144: {'shank_info': '0:1', 'xpos': 258, 'ypos': 360}
# CH145: {'shank_info': '0:1', 'xpos': 290, 'ypos': 360}
# CH146: {'shank_info': '0:1', 'xpos': 258, 'ypos': 375}
# CH147: {'shank_info': '0:1', 'xpos': 290, 'ypos': 375}
# CH148: {'shank_info': '0:1', 'xpos': 258, 'ypos': 390}
# CH149: {'shank_info': '0:1', 'xpos': 290, 'ypos': 390}
# CH150: {'shank_info': '0:1', 'xpos': 258, 'ypos': 405}
# CH151: {'shank_info': '0:1', 'xpos': 290, 'ypos': 405}
# CH152: {'shank_info': '0:1', 'xpos': 258, 'ypos': 420}
# CH153: {'shank_info': '0:1', 'xpos': 290, 'ypos': 420}
# CH154: {'shank_info': '0:1', 'xpos': 258, 'ypos': 435}
# CH155: {'shank_info': '0:1', 'xpos': 290, 'ypos': 435}
# CH156: {'shank_info': '0:1', 'xpos': 258, 'ypos': 450}
# CH157: {'shank_info': '0:1', 'xpos': 290, 'ypos': 450}
# CH158: {'shank_info': '0:1', 'xpos': 258, 'ypos': 465}
# CH159: {'shank_info': '0:1', 'xpos': 290, 'ypos': 465}
# CH160: {'shank_info': '0:1', 'xpos': 258, 'ypos': 480}
# CH161: {'shank_info': '0:1', 'xpos': 290, 'ypos': 480}
# CH162: {'shank_info': '0:1', 'xpos': 258, 'ypos': 495}
# CH163: {'shank_info': '0:1', 'xpos': 290, 'ypos': 495}
# CH164: {'shank_info': '0:1', 'xpos': 258, 'ypos': 510}
# CH165: {'shank_info': '0:1', 'xpos': 290, 'ypos': 510}
# CH166: {'shank_info': '0:1', 'xpos': 258, 'ypos': 525}
# CH167: {'shank_info': '0:1', 'xpos': 290, 'ypos': 525}
# CH168: {'shank_info': '0:1', 'xpos': 258, 'ypos': 540}
# CH169: {'shank_info': '0:1', 'xpos': 290, 'ypos': 540}
# CH170: {'shank_info': '0:1', 'xpos': 258, 'ypos': 555}
# CH171: {'shank_info': '0:1', 'xpos': 290, 'ypos': 555}
# CH172: {'shank_info': '0:1', 'xpos': 258, 'ypos': 570}
# CH173: {'shank_info': '0:1', 'xpos': 290, 'ypos': 570}
# CH174: {'shank_info': '0:1', 'xpos': 258, 'ypos': 585}
# CH175: {'shank_info': '0:1', 'xpos': 290, 'ypos': 585}
# CH176: {'shank_info': '0:1', 'xpos': 258, 'ypos': 600}
# CH177: {'shank_info': '0:1', 'xpos': 290, 'ypos': 600}
# CH178: {'shank_info': '0:1', 'xpos': 258, 'ypos': 615}
# CH179: {'shank_info': '0:1', 'xpos': 290, 'ypos': 615}
# CH180: {'shank_info': '0:1', 'xpos': 258, 'ypos': 630}
# CH181: {'shank_info': '0:1', 'xpos': 290, 'ypos': 630}
# CH182: {'shank_info': '0:1', 'xpos': 258, 'ypos': 645}
# CH183: {'shank_info': '0:1', 'xpos': 290, 'ypos': 645}
# CH184: {'shank_info': '0:1', 'xpos': 258, 'ypos': 660}
# CH185: {'shank_info': '0:1', 'xpos': 290, 'ypos': 660}
# CH186: {'shank_info': '0:1', 'xpos': 258, 'ypos': 675}
# CH187: {'shank_info': '0:1', 'xpos': 290, 'ypos': 675}
# CH188: {'shank_info': '0:1', 'xpos': 258, 'ypos': 690}
# CH189: {'shank_info': '0:1', 'xpos': 290, 'ypos': 690}
# CH190: {'shank_info': '0:1', 'xpos': 258, 'ypos': 705}
# CH191: {'shank_info': '0:1', 'xpos': 290, 'ypos': 705}
# CH192: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1440}
# CH193: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1440}
# CH194: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1455}
# CH195: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1455}
# CH196: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1470}
# CH197: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1470}
# CH198: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1485}
# CH199: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1485}
# CH200: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1500}
# CH201: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1500}
# CH202: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1515}
# CH203: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1515}
# CH204: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1530}
# CH205: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1530}
# CH206: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1545}
# CH207: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1545}
# CH208: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1560}
# CH209: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1560}
# CH210: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1575}
# CH211: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1575}
# CH212: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1590}
# CH213: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1590}
# CH214: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1605}
# CH215: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1605}
# CH216: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1620}
# CH217: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1620}
# CH218: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1635}
# CH219: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1635}
# CH220: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1650}
# CH221: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1650}
# CH222: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1665}
# CH223: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1665}
# CH224: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1680}
# CH225: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1680}
# CH226: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1695}
# CH227: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1695}
# CH228: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1710}
# CH229: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1710}
# CH230: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1725}
# CH231: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1725}
# CH232: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1740}
# CH233: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1740}
# CH234: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1755}
# CH235: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1755}
# CH236: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1770}
# CH237: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1770}
# CH238: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1785}
# CH239: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1785}
# CH240: {'shank_info': '0:1', 'xpos': 258, 'ypos': 720}
# CH241: {'shank_info': '0:1', 'xpos': 290, 'ypos': 720}
# CH242: {'shank_info': '0:1', 'xpos': 258, 'ypos': 735}
# CH243: {'shank_info': '0:1', 'xpos': 290, 'ypos': 735}
# CH244: {'shank_info': '0:1', 'xpos': 258, 'ypos': 750}
# CH245: {'shank_info': '0:1', 'xpos': 290, 'ypos': 750}
# CH246: {'shank_info': '0:1', 'xpos': 258, 'ypos': 765}
# CH247: {'shank_info': '0:1', 'xpos': 290, 'ypos': 765}
# CH248: {'shank_info': '0:1', 'xpos': 258, 'ypos': 780}
# CH249: {'shank_info': '0:1', 'xpos': 290, 'ypos': 780}
# CH250: {'shank_info': '0:1', 'xpos': 258, 'ypos': 795}
# CH251: {'shank_info': '0:1', 'xpos': 290, 'ypos': 795}
# CH252: {'shank_info': '0:1', 'xpos': 258, 'ypos': 810}
# CH253: {'shank_info': '0:1', 'xpos': 290, 'ypos': 810}
# CH254: {'shank_info': '0:1', 'xpos': 258, 'ypos': 825}
# CH255: {'shank_info': '0:1', 'xpos': 290, 'ypos': 825}
# CH256: {'shank_info': '0:1', 'xpos': 258, 'ypos': 840}
# CH257: {'shank_info': '0:1', 'xpos': 290, 'ypos': 840}
# CH258: {'shank_info': '0:1', 'xpos': 258, 'ypos': 855}
# CH259: {'shank_info': '0:1', 'xpos': 290, 'ypos': 855}
# CH260: {'shank_info': '0:1', 'xpos': 258, 'ypos': 870}
# CH261: {'shank_info': '0:1', 'xpos': 290, 'ypos': 870}
# CH262: {'shank_info': '0:1', 'xpos': 258, 'ypos': 885}
# CH263: {'shank_info': '0:1', 'xpos': 290, 'ypos': 885}
# CH264: {'shank_info': '0:1', 'xpos': 258, 'ypos': 900}
# CH265: {'shank_info': '0:1', 'xpos': 290, 'ypos': 900}
# CH266: {'shank_info': '0:1', 'xpos': 258, 'ypos': 915}
# CH267: {'shank_info': '0:1', 'xpos': 290, 'ypos': 915}
# CH268: {'shank_info': '0:1', 'xpos': 258, 'ypos': 930}
# CH269: {'shank_info': '0:1', 'xpos': 290, 'ypos': 930}
# CH270: {'shank_info': '0:1', 'xpos': 258, 'ypos': 945}
# CH271: {'shank_info': '0:1', 'xpos': 290, 'ypos': 945}
# CH272: {'shank_info': '0:1', 'xpos': 258, 'ypos': 960}
# CH273: {'shank_info': '0:1', 'xpos': 290, 'ypos': 960}
# CH274: {'shank_info': '0:1', 'xpos': 258, 'ypos': 975}
# CH275: {'shank_info': '0:1', 'xpos': 290, 'ypos': 975}
# CH276: {'shank_info': '0:1', 'xpos': 258, 'ypos': 990}
# CH277: {'shank_info': '0:1', 'xpos': 290, 'ypos': 990}
# CH278: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1005}
# CH279: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1005}
# CH280: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1020}
# CH281: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1020}
# CH282: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1035}
# CH283: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1035}
# CH284: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1050}
# CH285: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1050}
# CH286: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1065}
# CH287: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1065}
# CH288: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1800}
# CH289: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1800}
# CH290: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1815}
# CH291: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1815}
# CH292: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1830}
# CH293: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1830}
# CH294: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1845}
# CH295: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1845}
# CH296: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1860}
# CH297: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1860}
# CH298: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1875}
# CH299: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1875}
# CH300: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1890}
# CH301: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1890}
# CH302: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1905}
# CH303: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1905}
# CH304: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1920}
# CH305: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1920}
# CH306: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1935}
# CH307: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1935}
# CH308: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1950}
# CH309: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1950}
# CH310: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1965}
# CH311: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1965}
# CH312: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1980}
# CH313: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1980}
# CH314: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1995}
# CH315: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1995}
# CH316: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2010}
# CH317: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2010}
# CH318: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2025}
# CH319: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2025}
# CH320: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2040}
# CH321: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2040}
# CH322: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2055}
# CH323: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2055}
# CH324: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2070}
# CH325: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2070}
# CH326: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2085}
# CH327: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2085}
# CH328: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2100}
# CH329: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2100}
# CH330: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2115}
# CH331: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2115}
# CH332: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2130}
# CH333: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2130}
# CH334: {'shank_info': '0:1', 'xpos': 258, 'ypos': 2145}
# CH335: {'shank_info': '0:1', 'xpos': 290, 'ypos': 2145}
# CH336: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1080}
# CH337: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1080}
# CH338: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1095}
# CH339: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1095}
# CH340: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1110}
# CH341: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1110}
# CH342: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1125}
# CH343: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1125}
# CH344: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1140}
# CH345: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1140}
# CH346: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1155}
# CH347: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1155}
# CH348: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1170}
# CH349: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1170}
# CH350: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1185}
# CH351: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1185}
# CH352: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1200}
# CH353: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1200}
# CH354: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1215}
# CH355: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1215}
# CH356: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1230}
# CH357: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1230}
# CH358: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1245}
# CH359: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1245}
# CH360: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1260}
# CH361: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1260}
# CH362: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1275}
# CH363: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1275}
# CH364: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1290}
# CH365: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1290}
# CH366: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1305}
# CH367: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1305}
# CH368: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1320}
# CH369: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1320}
# CH370: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1335}
# CH371: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1335}
# CH372: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1350}
# CH373: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1350}
# CH374: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1365}
# CH375: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1365}
# CH376: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1380}
# CH377: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1380}
# CH378: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1395}
# CH379: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1395}
# CH380: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1410}
# CH381: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1410}
# CH382: {'shank_info': '0:1', 'xpos': 258, 'ypos': 1425}
# CH383: {'shank_info': '0:1', 'xpos': 290, 'ypos': 1425}
#
#
#
#
# NP_PROBE 0: electrodeConfigurationPreset = 'All Shanks 1-96'
# CH0: {'shank_info': '0:0', 'xpos': 8, 'ypos': 0}
# CH1: {'shank_info': '0:0', 'xpos': 40, 'ypos': 0}
# CH2: {'shank_info': '0:0', 'xpos': 8, 'ypos': 15}
# CH3: {'shank_info': '0:0', 'xpos': 40, 'ypos': 15}
# CH4: {'shank_info': '0:0', 'xpos': 8, 'ypos': 30}
# CH5: {'shank_info': '0:0', 'xpos': 40, 'ypos': 30}
# CH6: {'shank_info': '0:0', 'xpos': 8, 'ypos': 45}
# CH7: {'shank_info': '0:0', 'xpos': 40, 'ypos': 45}
# CH8: {'shank_info': '0:0', 'xpos': 8, 'ypos': 60}
# CH9: {'shank_info': '0:0', 'xpos': 40, 'ypos': 60}
# CH10: {'shank_info': '0:0', 'xpos': 8, 'ypos': 75}
# CH11: {'shank_info': '0:0', 'xpos': 40, 'ypos': 75}
# CH12: {'shank_info': '0:0', 'xpos': 8, 'ypos': 90}
# CH13: {'shank_info': '0:0', 'xpos': 40, 'ypos': 90}
# CH14: {'shank_info': '0:0', 'xpos': 8, 'ypos': 105}
# CH15: {'shank_info': '0:0', 'xpos': 40, 'ypos': 105}
# CH16: {'shank_info': '0:0', 'xpos': 8, 'ypos': 120}
# CH17: {'shank_info': '0:0', 'xpos': 40, 'ypos': 120}
# CH18: {'shank_info': '0:0', 'xpos': 8, 'ypos': 135}
# CH19: {'shank_info': '0:0', 'xpos': 40, 'ypos': 135}
# CH20: {'shank_info': '0:0', 'xpos': 8, 'ypos': 150}
# CH21: {'shank_info': '0:0', 'xpos': 40, 'ypos': 150}
# CH22: {'shank_info': '0:0', 'xpos': 8, 'ypos': 165}
# CH23: {'shank_info': '0:0', 'xpos': 40, 'ypos': 165}
# CH24: {'shank_info': '0:0', 'xpos': 8, 'ypos': 180}
# CH25: {'shank_info': '0:0', 'xpos': 40, 'ypos': 180}
# CH26: {'shank_info': '0:0', 'xpos': 8, 'ypos': 195}
# CH27: {'shank_info': '0:0', 'xpos': 40, 'ypos': 195}
# CH28: {'shank_info': '0:0', 'xpos': 8, 'ypos': 210}
# CH29: {'shank_info': '0:0', 'xpos': 40, 'ypos': 210}
# CH30: {'shank_info': '0:0', 'xpos': 8, 'ypos': 225}
# CH31: {'shank_info': '0:0', 'xpos': 40, 'ypos': 225}
# CH32: {'shank_info': '0:0', 'xpos': 8, 'ypos': 240}
# CH33: {'shank_info': '0:0', 'xpos': 40, 'ypos': 240}
# CH34: {'shank_info': '0:0', 'xpos': 8, 'ypos': 255}
# CH35: {'shank_info': '0:0', 'xpos': 40, 'ypos': 255}
# CH36: {'shank_info': '0:0', 'xpos': 8, 'ypos': 270}
# CH37: {'shank_info': '0:0', 'xpos': 40, 'ypos': 270}
# CH38: {'shank_info': '0:0', 'xpos': 8, 'ypos': 285}
# CH39: {'shank_info': '0:0', 'xpos': 40, 'ypos': 285}
# CH40: {'shank_info': '0:0', 'xpos': 8, 'ypos': 300}
# CH41: {'shank_info': '0:0', 'xpos': 40, 'ypos': 300}
# CH42: {'shank_info': '0:0', 'xpos': 8, 'ypos': 315}
# CH43: {'shank_info': '0:0', 'xpos': 40, 'ypos': 315}
# CH44: {'shank_info': '0:0', 'xpos': 8, 'ypos': 330}
# CH45: {'shank_info': '0:0', 'xpos': 40, 'ypos': 330}
# CH46: {'shank_info': '0:0', 'xpos': 8, 'ypos': 345}
# CH47: {'shank_info': '0:0', 'xpos': 40, 'ypos': 345}
# CH48: {'shank_info': '0:1', 'xpos': 258, 'ypos': 0}
# CH49: {'shank_info': '0:1', 'xpos': 290, 'ypos': 0}
# CH50: {'shank_info': '0:1', 'xpos': 258, 'ypos': 15}
# CH51: {'shank_info': '0:1', 'xpos': 290, 'ypos': 15}
# CH52: {'shank_info': '0:1', 'xpos': 258, 'ypos': 30}
# CH53: {'shank_info': '0:1', 'xpos': 290, 'ypos': 30}
# CH54: {'shank_info': '0:1', 'xpos': 258, 'ypos': 45}
# CH55: {'shank_info': '0:1', 'xpos': 290, 'ypos': 45}
# CH56: {'shank_info': '0:1', 'xpos': 258, 'ypos': 60}
# CH57: {'shank_info': '0:1', 'xpos': 290, 'ypos': 60}
# CH58: {'shank_info': '0:1', 'xpos': 258, 'ypos': 75}
# CH59: {'shank_info': '0:1', 'xpos': 290, 'ypos': 75}
# CH60: {'shank_info': '0:1', 'xpos': 258, 'ypos': 90}
# CH61: {'shank_info': '0:1', 'xpos': 290, 'ypos': 90}
# CH62: {'shank_info': '0:1', 'xpos': 258, 'ypos': 105}
# CH63: {'shank_info': '0:1', 'xpos': 290, 'ypos': 105}
# CH64: {'shank_info': '0:1', 'xpos': 258, 'ypos': 120}
# CH65: {'shank_info': '0:1', 'xpos': 290, 'ypos': 120}
# CH66: {'shank_info': '0:1', 'xpos': 258, 'ypos': 135}
# CH67: {'shank_info': '0:1', 'xpos': 290, 'ypos': 135}
# CH68: {'shank_info': '0:1', 'xpos': 258, 'ypos': 150}
# CH69: {'shank_info': '0:1', 'xpos': 290, 'ypos': 150}
# CH70: {'shank_info': '0:1', 'xpos': 258, 'ypos': 165}
# CH71: {'shank_info': '0:1', 'xpos': 290, 'ypos': 165}
# CH72: {'shank_info': '0:1', 'xpos': 258, 'ypos': 180}
# CH73: {'shank_info': '0:1', 'xpos': 290, 'ypos': 180}
# CH74: {'shank_info': '0:1', 'xpos': 258, 'ypos': 195}
# CH75: {'shank_info': '0:1', 'xpos': 290, 'ypos': 195}
# CH76: {'shank_info': '0:1', 'xpos': 258, 'ypos': 210}
# CH77: {'shank_info': '0:1', 'xpos': 290, 'ypos': 210}
# CH78: {'shank_info': '0:1', 'xpos': 258, 'ypos': 225}
# CH79: {'shank_info': '0:1', 'xpos': 290, 'ypos': 225}
# CH80: {'shank_info': '0:1', 'xpos': 258, 'ypos': 240}
# CH81: {'shank_info': '0:1', 'xpos': 290, 'ypos': 240}
# CH82: {'shank_info': '0:1', 'xpos': 258, 'ypos': 255}
# CH83: {'shank_info': '0:1', 'xpos': 290, 'ypos': 255}
# CH84: {'shank_info': '0:1', 'xpos': 258, 'ypos': 270}
# CH85: {'shank_info': '0:1', 'xpos': 290, 'ypos': 270}
# CH86: {'shank_info': '0:1', 'xpos': 258, 'ypos': 285}
# CH87: {'shank_info': '0:1', 'xpos': 290, 'ypos': 285}
# CH88: {'shank_info': '0:1', 'xpos': 258, 'ypos': 300}
# CH89: {'shank_info': '0:1', 'xpos': 290, 'ypos': 300}
# CH90: {'shank_info': '0:1', 'xpos': 258, 'ypos': 315}
# CH91: {'shank_info': '0:1', 'xpos': 290, 'ypos': 315}
# CH92: {'shank_info': '0:1', 'xpos': 258, 'ypos': 330}
# CH93: {'shank_info': '0:1', 'xpos': 290, 'ypos': 330}
# CH94: {'shank_info': '0:1', 'xpos': 258, 'ypos': 345}
# CH95: {'shank_info': '0:1', 'xpos': 290, 'ypos': 345}
# CH96: {'shank_info': '0:0', 'xpos': 8, 'ypos': 360}
# CH97: {'shank_info': '0:0', 'xpos': 40, 'ypos': 360}
# CH98: {'shank_info': '0:0', 'xpos': 8, 'ypos': 375}
# CH99: {'shank_info': '0:0', 'xpos': 40, 'ypos': 375}
# CH100: {'shank_info': '0:0', 'xpos': 8, 'ypos': 390}
# CH101: {'shank_info': '0:0', 'xpos': 40, 'ypos': 390}
# CH102: {'shank_info': '0:0', 'xpos': 8, 'ypos': 405}
# CH103: {'shank_info': '0:0', 'xpos': 40, 'ypos': 405}
# CH104: {'shank_info': '0:0', 'xpos': 8, 'ypos': 420}
# CH105: {'shank_info': '0:0', 'xpos': 40, 'ypos': 420}
# CH106: {'shank_info': '0:0', 'xpos': 8, 'ypos': 435}
# CH107: {'shank_info': '0:0', 'xpos': 40, 'ypos': 435}
# CH108: {'shank_info': '0:0', 'xpos': 8, 'ypos': 450}
# ...
# CH106: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3315}
# CH107: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3315}
# CH108: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3330}
# CH109: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3330}
# CH110: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3345}
# CH111: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3345}
# CH112: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3360}
# CH113: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3360}
# CH114: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3375}
# CH115: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3375}
# CH116: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3390}
# CH117: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3390}
# CH118: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3405}
# CH119: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3405}
# CH120: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3420}
# CH121: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3420}
# CH122: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3435}
# CH123: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3435}
# CH124: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3450}
# CH125: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3450}
# CH126: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3465}
# CH127: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3465}
# CH128: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3480}
# CH129: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3480}
# CH130: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3495}
# CH131: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3495}
# CH132: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3510}
# CH133: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3510}
# CH134: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3525}
# CH135: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3525}
# CH136: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3540}
# CH137: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3540}
# CH138: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3555}
# CH139: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3555}
# CH140: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3570}
# CH141: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3570}
# CH142: {'shank_info': '1:0', 'xpos': 8, 'ypos': 3585}
# CH143: {'shank_info': '1:0', 'xpos': 40, 'ypos': 3585}
# CH144: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3240}
# CH145: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3240}
# CH146: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3255}
# CH147: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3255}
# CH148: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3270}
# CH149: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3270}
# CH150: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3285}
# CH151: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3285}
# CH152: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3300}
# CH153: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3300}
# CH154: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3315}
# CH155: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3315}
# CH156: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3330}
# CH157: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3330}
# CH158: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3345}
# CH159: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3345}
# CH160: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3360}
# CH161: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3360}
# CH162: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3375}
# CH163: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3375}
# CH164: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3390}
# CH165: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3390}
# CH166: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3405}
# CH167: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3405}
# CH168: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3420}
# CH169: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3420}
# CH170: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3435}
# CH171: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3435}
# CH172: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3450}
# CH173: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3450}
# CH174: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3465}
# CH175: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3465}
# CH176: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3480}
# CH177: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3480}
# CH178: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3495}
# CH179: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3495}
# CH180: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3510}
# CH181: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3510}
# CH182: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3525}
# CH183: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3525}
# CH184: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3540}
# CH185: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3540}
# CH186: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3555}
# CH187: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3555}
# CH188: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3570}
# CH189: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3570}
# CH190: {'shank_info': '1:1', 'xpos': 258, 'ypos': 3585}
# CH191: {'shank_info': '1:1', 'xpos': 290, 'ypos': 3585}
# CH192: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2880}
# CH193: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2880}
# CH194: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2895}
# CH195: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2895}
# CH196: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2910}
# CH197: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2910}
# CH198: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2925}
# CH199: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2925}
# CH200: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2940}
# CH201: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2940}
# CH202: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2955}
# CH203: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2955}
# CH204: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2970}
# CH205: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2970}
# CH206: {'shank_info': '1:2', 'xpos': 508, 'ypos': 2985}
# CH207: {'shank_info': '1:2', 'xpos': 540, 'ypos': 2985}
# CH208: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3000}
# CH209: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3000}
# CH210: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3015}
# CH211: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3015}
# CH212: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3030}
# CH213: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3030}
# CH214: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3045}
# CH215: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3045}
# CH216: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3060}
# CH217: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3060}
# CH218: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3075}
# CH219: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3075}
# CH220: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3090}
# CH221: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3090}
# CH222: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3105}
# CH223: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3105}
# CH224: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3120}
# CH225: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3120}
# CH226: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3135}
# CH227: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3135}
# CH228: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3150}
# CH229: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3150}
# CH230: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3165}
# CH231: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3165}
# CH232: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3180}
# CH233: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3180}
# CH234: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3195}
# CH235: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3195}
# CH236: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3210}
# CH237: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3210}
# CH238: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3225}
# CH239: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3225}
# CH240: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2880}
# CH241: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2880}
# CH242: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2895}
# CH243: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2895}
# CH244: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2910}
# CH245: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2910}
# CH246: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2925}
# CH247: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2925}
# CH248: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2940}
# CH249: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2940}
# CH250: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2955}
# CH251: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2955}
# CH252: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2970}
# CH253: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2970}
# CH254: {'shank_info': '1:3', 'xpos': 758, 'ypos': 2985}
# CH255: {'shank_info': '1:3', 'xpos': 790, 'ypos': 2985}
# CH256: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3000}
# CH257: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3000}
# CH258: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3015}
# CH259: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3015}
# CH260: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3030}
# CH261: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3030}
# CH262: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3045}
# CH263: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3045}
# CH264: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3060}
# CH265: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3060}
# CH266: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3075}
# CH267: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3075}
# CH268: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3090}
# CH269: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3090}
# CH270: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3105}
# CH271: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3105}
# CH272: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3120}
# CH273: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3120}
# CH274: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3135}
# CH275: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3135}
# CH276: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3150}
# CH277: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3150}
# CH278: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3165}
# CH279: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3165}
# CH280: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3180}
# CH281: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3180}
# CH282: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3195}
# CH283: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3195}
# CH284: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3210}
# CH285: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3210}
# CH286: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3225}
# CH287: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3225}
# CH288: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3240}
# CH289: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3240}
# CH290: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3255}
# CH291: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3255}
# CH292: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3270}
# CH293: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3270}
# CH294: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3285}
# CH295: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3285}
# CH296: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3300}
# CH297: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3300}
# CH298: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3315}
# CH299: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3315}
# CH300: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3330}
# CH301: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3330}
# CH302: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3345}
# CH303: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3345}
# CH304: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3360}
# CH305: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3360}
# CH306: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3375}
# CH307: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3375}
# CH308: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3390}
# CH309: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3390}
# CH310: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3405}
# CH311: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3405}
# CH312: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3420}
# CH313: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3420}
# CH314: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3435}
# CH315: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3435}
# CH316: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3450}
# CH317: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3450}
# CH318: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3465}
# CH319: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3465}
# CH320: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3480}
# CH321: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3480}
# CH322: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3495}
# CH323: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3495}
# CH324: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3510}
# CH325: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3510}
# CH326: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3525}
# CH327: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3525}
# CH328: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3540}
# CH329: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3540}
# CH330: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3555}
# CH331: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3555}
# CH332: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3570}
# CH333: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3570}
# CH334: {'shank_info': '1:2', 'xpos': 508, 'ypos': 3585}
# CH335: {'shank_info': '1:2', 'xpos': 540, 'ypos': 3585}
# CH336: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3240}
# CH337: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3240}
# CH338: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3255}
# CH339: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3255}
# CH340: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3270}
# CH341: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3270}
# CH342: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3285}
# CH343: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3285}
# CH344: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3300}
# CH345: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3300}
# CH346: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3315}
# CH347: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3315}
# CH348: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3330}
# CH349: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3330}
# CH350: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3345}
# CH351: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3345}
# CH352: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3360}
# CH353: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3360}
# CH354: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3375}
# CH355: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3375}
# CH356: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3390}
# CH357: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3390}
# CH358: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3405}
# CH359: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3405}
# CH360: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3420}
# CH361: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3420}
# CH362: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3435}
# CH363: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3435}
# CH364: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3450}
# CH365: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3450}
# CH366: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3465}
# CH367: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3465}
# CH368: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3480}
# CH369: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3480}
# CH370: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3495}
# CH371: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3495}
# CH372: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3510}
# CH373: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3510}
# CH374: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3525}
# CH375: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3525}
# CH376: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3540}
# CH377: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3540}
# CH378: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3555}
# CH379: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3555}
# CH380: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3570}
# CH381: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3570}
# CH382: {'shank_info': '1:3', 'xpos': 758, 'ypos': 3585}
# CH383: {'shank_info': '1:3', 'xpos': 790, 'ypos': 3585}
#
#
#
#
# settings_2_probe_0
# settings_2_probe_1
# settings_3_probe_0
# settings_3_probe_1
# settings_4_probe_0
# settings_4_probe_1
# settings_5_probe_0
# settings_5_probe_1
# settings_6_probe_0
# settings_6_probe_1
# settings_7_probe_0
# settings_7_probe_1
# settings_8_probe_0
# settings_8_probe_1
# settings_9_probe_0
# settings_9_probe_1
# settings_10_probe_0
# settings_10_probe_1
# settings_11_probe_0
# settings_11_probe_1
# settings_12_probe_0
# settings_12_probe_1
# settings_13_probe_0
# settings_13_probe_1

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

# Plot electrode positions for each probe!
for probe_id, probe_data in all_probes_data.items():
    electrode_config_name = probe_data["electrode_config_name"]
    channel_map = probe_data["channel_map"]
    print(f"Plotting coordinates for '{electrode_config_name}'")
    
    x_coords = []
    y_coords = []
    labels = []

    for channel_num, info in channel_map.items():
        x_coords.append(info.get("xpos"))
        y_coords.append(info.get("ypos"))
        labels.append(f"{channel_num}")
    
    # Plot electrode coordinates
    plt.figure(figsize=(8, 6))
    plt.scatter(x_coords, y_coords, color='blue', s=2)

    # Add channel number next to each electrode
    for i, label in enumerate(labels):
        plt.annotate(label, (x_coords[i], y_coords[i]), textcoords="offset points", xytext=(2, 0), ha='left', fontsize=9)

    plt.title(f"Neuropixels 2.0 Electrode Positions '{electrode_config_name}'")
    plt.xlabel("X Position")
    plt.ylabel("Y Position")
    plt.grid(True)
    plt.show()
# Out:
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 2 Bank A'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 3 Bank A'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 4 Bank A'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 1 Bank C'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 2 Bank C'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 3 Bank C'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'Shank 4 Bank C'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'All Shanks 97-192'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'All Shanks 193-288'
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'All Shanks 289-384'
# /var/folders/qw/_sndq4457jd616hb6zx68mw80000gn/T/ipykernel_88344/303241753.py:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(8, 6))
# Plotting coordinates for 'All Shanks 1-96'
# Plotting coordinates for 'All Shanks 385-480'
